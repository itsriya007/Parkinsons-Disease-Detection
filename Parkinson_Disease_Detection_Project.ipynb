# %%
# !pip install pickle5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
import plotly.offline as iplot
import plotly as py

# %%
parkinson = pd.read_csv('parkinsons.data')

# %%
parkinson.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson.shape
# Out:
# (195, 24)

# %%
parkinson.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson.duplicated().sum()
# Out:
# 0

# %%
parkinson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
for i in parkinson.columns:
  print("******************************************", i ,
        "********************************************")
  print()
  print(set(parkinson[i].tolist()))
  print()
# Out:
# ****************************************** name ********************************************
#
# ...

# %%
parkinson['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# finding the distribution of the dataset

def displot(col):
  sns.displot(parkinson[col])
  plt.show()

for i in list(parkinson.columns)[1:]:
  displot(i)

# %%
#outlier

def boxplots(col):
  sns.boxplot(parkinson[col])
  plt.show()

for i in list(parkinson.columns)[1:]:
  boxplots(i)

# %%
# define correlation
cols_to_drop = parkinson.columns[parkinson.columns.str.contains('name')]

parkinson.drop(cols_to_drop, axis=1, inplace=True)

# %%
plt.figure(figsize=(20,20))
corr = parkinson.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
parkinson.groupby(['status'])[["MDVP:Fo(Hz)","MDVP:Fhi(Hz)"]].mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)
# status
# 0        181.937771    223.636750
# 1        145.180762    188.441463

# %%
X = parkinson.drop(['status'], axis=1)
Y = parkinson['status']

# %%
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
Y.shape
# Out:
# (195,)

# %%
X.shape
# Out:
# (195, 22)

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
X_ros, Y_ros = ros.fit_resample(X,Y)
print(Y.value_counts())
print("###########")
print(Y_ros.value_counts())
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64
# ###########
# status
# 1    147
# 0    147
# Name: count, dtype: int64

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler((-1,1))
X = scaler.fit_transform(X_ros)
Y = Y_ros

# %%
X.shape
# Out:
# (294, 22)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(.95)
X_pca = pca.fit_transform(X)
print(X.shape)
print(X_pca.shape)
# Out:
# (294, 22)
# (294, 8)

# %%
pd.DataFrame(X_pca)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, Y, test_size=0.2, random_state=1)

# %%
list_met = []
list_accuracy = []

# logistic regression

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(C=0.4, max_iter= 1000, solver='liblinear')
lr = classifier.fit(X_train, y_train)
#Prediction
y_pred = classifier.predict(X_test)
#Accuracy
accuracy_LR = accuracy_score(y_test, y_pred)

# Model 2

from sklearn.tree import DecisionTreeClassifier
classifier2 = DecisionTreeClassifier(random_state=14)
dt = classifier2.fit(X_train, y_train)
#Prediction
y_pred2 = classifier2.predict(X_test)
#accuracy
accuracy_DT = accuracy_score(y_test, y_pred2)

# Model 3
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier(random_state=14)
rf = classifier3.fit(X_train, y_train)
#predict
y_pred3 = classifier3.predict(X_test)
#accuracy
accuracy_RF = accuracy_score(y_test, y_pred3)
#Model 4
classifier4 = RandomForestClassifier(criterion = 'entropy', random_state=14)
rfe = classifier4.fit(X_train, y_train)
#predict
y_pred4 = classifier4.predict(X_test)
#evaluation
accuracy_RFE = accuracy_score(y_test, y_pred)

#Model 5
from sklearn.svm import SVC
model_svm = SVC()
SVM = model_svm.fit(X_train, y_train)
#predict
y_pred5 = model_svm.predict(X_test)
#evaluation
accuracy_SVC = accuracy_score(y_test, y_pred5)

# Model 6
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()
knn = model_knn.fit(X_train, y_train)
#predict
pred_knn = model_knn.predict(X_test)
accuracy_knn = accuracy_score(y_test, pred_knn)

#model 7
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb = gnb.fit(X_train, y_train)
#predict
pred_gnb = gnb.predict(X_test)
#evaluation
accuracy_GB = accuracy_score(y_test, pred_gnb)

#model 8
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
bnb = model.fit(X_train, y_train)
#predict
pred_bnb = bnb.predict(X_test)
#evaluation
accuracy_BB = accuracy_score(y_test, pred_bnb)

# combine all the model using voting classifier model

from sklearn.ensemble import VotingClassifier

evc = VotingClassifier(estimators = [('lr',lr), ('DT', dt), ('RF',rf), ('RFE',rfe),('SVC',svc), ('KNN',knn), ('GNB',gnb),('BNB',bnb)], voting='hard',
                                     flatten_transform=True)
model_evc = evc.fit(X_train, y_train)
#prediction
pred_evc = evc.predict(X_test)
#evaluate
accuracy_evc = accuracy_score(y_test, pred_evc)

list1 = ["Logistic Regression", 'Decision Tree', 'RandomForest Gini', 'RandomForest Entropy', 'Support Vector', 'K Nearest Neigbors', 'GaussianNB', 'BernoulliNB', 'Voting CLassifier']

list2 = [accuracy_LR, accuracy_DT, accuracy_RF, accuracy_RFE, accuracy_SVC, accuracy_knn, accuracy_GB, accuracy_BB, accuracy_evc]

list3= [classifier, classifier2, classifier3, classifier4, model_svm, model_knn, gnb, model, model_evc ]

parkinson_accuracy = pd.DataFrame({'Method Used': list1, "Accuracy":list2})
print(parkinson_accuracy)

charts = sns.barplot(x = 'Method Used', y = 'Accuracy', data=parkinson_accuracy)
charts.set_xlabel(charts.get_xlabel(), rotation=90)
plt.figure(figsize=(80, 80))
print(charts)
# Out:
#             Method Used  Accuracy
# 0   Logistic Regression  0.745763
# 1         Decision Tree  0.932203
# 2     RandomForest Gini  0.983051
# 3  RandomForest Entropy  0.745763
# 4        Support Vector  0.915254
# 5    K Nearest Neigbors  0.983051
# 6            GaussianNB  0.796610
# 7           BernoulliNB  0.677966
# 8     Voting CLassifier  0.949153
# Axes(0.125,0.11;0.775x0.77)

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
y_pred_xgb = model_xgb.predict(X_test)
print(accuracy_score(y_test,y_pred_xgb))
# Out:
# 0.9661016949152542

# %%
# other evaluation methods
y_pred4_train = classifier4.predict(X_train)
y_pred4_test = classifier4.predict(X_test)

#knn
pred_knn_train = model_knn.predict(X_train)
pred_knn_test = model_knn.predict(X_test)


#confusion matrix
print("Confusion Matrix for Random forest model")
print(confusion_matrix(y_train, y_pred4_train))
print("************"*5)
print(confusion_matrix(y_test, y_pred4_test))

print("************"*5)
print("Confusion Matrix for KNN model")
print(confusion_matrix(y_train, pred_knn_train))
print("************"*5)
print(confusion_matrix(y_test, pred_knn_test))
# Out:
# Confusion Matrix for Random forest model
# [[118   0]
#  [  0 117]]
# ************************************************************
# [[29  0]
#  [ 1 29]]
# ************************************************************
# Confusion Matrix for KNN model
# [[118   0]
#  [  6 111]]
# ************************************************************
# [[29  0]
#  [ 1 29]]

# %%
print(classification_report(y_train, y_pred4_train))
print("***********"*5)
print(classification_report(y_test, y_pred4_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       118
#            1       1.00      1.00      1.00       117
#
#     accuracy                           1.00       235
#    macro avg       1.00      1.00      1.00       235
# weighted avg       1.00      1.00      1.00       235
#
# *******************************************************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       1.00      0.97      0.98        30
#
#     accuracy                           0.98        59
#    macro avg       0.98      0.98      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
print(classification_report(y_train, pred_knn_train))
print("***********"*5)
print(classification_report(y_test, pred_knn_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       118
#            1       1.00      0.95      0.97       117
#
#     accuracy                           0.97       235
#    macro avg       0.98      0.97      0.97       235
# weighted avg       0.98      0.97      0.97       235
#
# *******************************************************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       1.00      0.97      0.98        30
#
#     accuracy                           0.98        59
#    macro avg       0.98      0.98      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
#roc and curve

def plot_roc(rfe, X_test, y_test):
  probabilities = model.predict_proba(np.array(X_test))
  predicitions = probabilities
  fpr, tpr, threshold = roc_curve(y_test, predicitions[:,1])
  roc_auc = auc(fpr, tpr)

  plt.title("Receiver Operating Characteristics")
  plt.plot(fpr, tpr, 'b', label= 'AUC = %0.2f' % roc_auc)
  plt.legend(loc='lower right')
  plt.plot([0,1], [0,1], 'r--')
  plt.xlim([0,1])
  plt.ylim([0,1])
  plt.ylabel("True Postiive Rate")
  plt.xlabel("False Positive Rate")
  plt.show()

# %%
plot_roc (rfe, X_test, y_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state = 1 )

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras import Sequential

# %%
model = Sequential()
model.add(Dense(32, activation= "relu", input_dim=22))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                736
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 1825 (7.13 KB)
# Trainable params: 1825 (7.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", metrics=['accuracy'])
model.fit(x_train, Y_train, batch_size=32, epochs=200, validation_data=(x_test, Y_test))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 58ms/step - loss: 0.6645 - accuracy: 0.5957 - val_loss: 0.6319 - val_accuracy: 0.7627
# Epoch 2/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6159 - accuracy: 0.7404 - val_loss: 0.6088 - val_accuracy: 0.7119
# Epoch 3/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5828 - accuracy: 0.7574 - val_loss: 0.5904 - val_accuracy: 0.6441
# Epoch 4/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5549 - accuracy: 0.7617 - val_loss: 0.5673 - val_accuracy: 0.7288
# Epoch 5/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5293 - accuracy: 0.7702 - val_loss: 0.5506 - val_accuracy: 0.7458
# Epoch 6/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5040 - accuracy: 0.7957 - val_loss: 0.5359 - val_accuracy: 0.7458
# Epoch 7/200
# ...

# %%
input_data = (  1.03983688,  0.17237666,  1.67879945, -0.83410268, -0.94428847,
       -0.73207722, -0.75558996, -0.73211087, -0.93702927, -0.90522785,
       -0.94302224, -0.83727105, -0.87945488, -0.94333241, -0.59315683,
        1.97537236, -0.29114466,  0.35627085, -1.24057161, -0.59088115,
       -2.2231008 , -1.20119397)

np_data = np.asanyarray(input_data)
prediction = model.predict(np_data.reshape(1,-1))

if prediction == 1:
    print("this person has parkinson disease")
else:
    print("this person has no parkinson disease")
# Out:
# 1/1 [==============================] - 0s 112ms/step
# this person has no parkinson disease

# %%
import pickle
pickle.dump(svc,open('model.pkl', 'wb'))
